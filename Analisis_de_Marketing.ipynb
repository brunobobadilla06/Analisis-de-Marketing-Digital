# %% [markdown]
# <a href="https://colab.research.google.com/github/brunobobadilla06/Analisis-de-Marketing-Digital/blob/main/Analisis_de_Marketing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargar data set
df = pd.read_csv('https://raw.githubusercontent.com/brunobobadilla06/Analisis-de-Marketing-Digital/refs/heads/main/marketing_digital_2024.csv', parse_dates=['Fecha'])

# Crear metricas derivadas
df

# Mostrar data set
df.head()
# Out:
#        Fecha             Campaña          Canal  Impresiones  Clics  \
# 0 2024-01-05  Lanzamiento Verano     Google Ads        48000   1600
# 1 2024-01-15  Lanzamiento Verano  Instagram Ads        52000   1700
# 2 2024-01-22   Promo Auriculares   Facebook Ads        45000   1250
# 3 2024-02-03     Rebajas Febrero     Google Ads        53000   1450
# 4 2024-02-17     Rebajas Febrero  Instagram Ads        60000   1550
#
#    Conversiones  Gasto  Ingresos  Región
# 0           140   1200      4800   Norte
# 1           110   1050      3700  Centro
# 2            95    890      2800     Sur
# 3           130   1100      4200   Oeste
# 4           115    980      3900  Centro
